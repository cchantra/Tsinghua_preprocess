# %%
import cv2
import dlib
import collections
import numpy as np
import os
import glob

# %%
FACIAL_LANDMARKS_IDXS = collections.OrderedDict([
	("mouth", (48, 68)),
	("right_eyebrow", (17, 22)),
	("left_eyebrow", (22, 27)),
	("right_eye", (36, 42)),
	("left_eye", (42, 48)),
	("nose", (27, 35)),
	("jaw", (0, 17))
])

# %%
def visualize_facial_landmarks(image, shape, colors=None, alpha=0.75):
	# create two copies of the input image -- one for the
	# overlay and one for the final output image
	overlay = image.copy()
	output = image.copy()
 
	# if the colors list is None, initialize it with a unique
	# color for each facial landmark region
	if colors is None:
		colors = [(19, 199, 109), (79, 76, 240), (230, 159, 23),
			(168, 100, 168), (158, 163, 32),
			(163, 38, 32), (180, 42, 220)]
# loop over the facial landmark regions individually
	for (i, name) in enumerate(FACIAL_LANDMARKS_IDXS.keys()):
		# grab the (x, y)-coordinates associated with the
		# face landmark
		(j, k) = FACIAL_LANDMARKS_IDXS[name]
		pts = shape[j:k]
 
		# check if are supposed to draw the jawline
		if name == "jaw":
			# since the jawline is a non-enclosed facial region,
			# just draw lines between the (x, y)-coordinates
			for l in range(1, len(pts)):
				ptA = tuple(pts[l - 1])
				ptB = tuple(pts[l])
       ## print(ptA)
        #print(ptB)
 
				cv2.line(overlay, ptA, ptB, colors[i], 2)
 
		# otherwise, compute the convex hull of the facial
		# landmark coordinates points and display it
		else:
			hull = cv2.convexHull(pts)
			cv2.drawContours(overlay, [hull], -1, colors[i], -1)
        # apply the transparent overlay
	cv2.addWeighted(overlay, alpha, output, 1 - alpha, 0, output)
 
	# return the output image
	return output

# %%
# !wget https://github.com/italojs/facial-landmarks-recognition/raw/master/shape_predictor_68_face_landmarks.dat
# Out:
# --2021-08-23 08:20:04--  https://github.com/italojs/facial-landmarks-recognition/raw/master/shape_predictor_68_face_landmarks.dat
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/italojs/facial-landmarks-recognition/master/shape_predictor_68_face_landmarks.dat [following]
# --2021-08-23 08:20:04--  https://raw.githubusercontent.com/italojs/facial-landmarks-recognition/master/shape_predictor_68_face_landmarks.dat
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 99693937 (95M) [application/octet-stream]
# Saving to: ‘shape_predictor_68_face_landmarks.dat’
#
# shape_predictor_68_ 100%[===================>]  95.08M   217MB/s    in 0.4s
#
# 2021-08-23 08:20:05 (217 MB/s) - ‘shape_predictor_68_face_landmarks.dat’ saved [99693937/99693937]

# %%
detector = dlib.get_frontal_face_detector() #Face detector
predictor = dlib.shape_predictor("./shape_predictor_68_face_landmarks.dat") #Landmark identifier. Set the filename to whatever you named the downloaded file

# %%
from google.colab import drive
drive.mount('/content/drive')
source_dir = '/content/drive/MyDrive/Tsinghua FED images'
dest_dir = '/content/drive/MyDrive/Tsinghua FED_class'  
preprocess_dir = '/content/drive/MyDrive/Tsinghua FED_landmarks68' # landmarks of each subject_emotion

data_dir = dest_dir
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
IMG_HEIGHT=224
IMG_WIDTH=224

# %%
import shutil
if not os.path.exists(preprocess_dir ):
  os.mkdir(preprocess_dir)
else:
  try:
    shutil.rmtree(preprocess_dir )
    os.mkdir(preprocess_dir)
  except:
    pass

# %%
def detect_landmark(clahe_image):
  detections = detector(clahe_image, 1) #Detect the faces in the image
  #vec = np.empty([68, 2], dtype = int)
  vec = []
  for k,d in enumerate(detections): #For each detected face
        
    shape = predictor(clahe_image, d) #Get coordinates
    
    for i in range(0,68): #There are 68 landmark points on each face
	    #vec[i][0] = shape.part(i).x
	    #vec[i][1] = shape.part(i).y
      vec.append([shape.part(i).x,shape.part(i).y])
        #out_frame = visualize_facial_landmarks(clahe_image,vec)
        #        cv2.circle(frame, (shape.part(i).x, shape.part(i).y), 1, (0,0,255), thickness=2) #For each point, draw a red circle with thickness2 on the original frame

        #cv2.imshow("image", out_frame) #Display the frame
    break
  return vec

# %% [markdown]
# scale image to 224x224
# and find landmarks based on reduced image

# %%
for file in glob.glob(source_dir+"/*.jpg"):
 
  image = cv2.resize(cv2.imread(file,cv2.COLOR_BGR2GRAY), (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
  filepath, file_extension = os.path.splitext(file)

  filename = filepath.split('/')[-1] # take last item as filename w/o ext
  array = filename.split('_')
  #subject_name =   array[0]
  #emotion = array[1]
  print('process ',filename)
  filepath = preprocess_dir + '/'+filename+'_landmark68.csv'
  f = open(filepath,'w')

  lm = detect_landmark(image)
  for item in  lm :
    
    f.write('%.4f,%.4f\n'%(item[0],item[1]))
  f.close()
# Out:
# process  O49F-65_fear
# process  O04F-76_content
# process  O04F-76_happy
# process  O04F-76_fear
# process  O04F-76_disgust
# process  O04F-76_anger
# process  O04F-76_surprise
# process  O04F-76_neutral
# process  O04F-76_sad
# process  O07F-65_disgust
# process  O07F-65_anger
# process  O07F-65_content
# process  O07F-65_sad
# process  O07F-65_neutral
# process  O07F-65_fear
# process  O07F-65_surprise
# process  O07F-65_happy
# process  O08M-65_neutral
# process  O08M-65_fear
# process  O08M-65_happy
# process  O08M-65_content
# process  O08M-65_disgust
# process  O08M-65_anger
# process  O08M-65_sad
# process  O08M-65_surprise
# process  O09F-64_content
# process  O09F-64_anger
# process  O09F-64_fear
# process  O09F-64_disgust
# process  O09F-64_happy
# process  O09F-64_neutral
# process  O10F-60_fear
# process  O10F-60_disgust
# process  O10F-60_anger
# process  O10F-60_content
# process  O09F-64_sad
# process  O09F-64_surprise
# process  O10F-60_happy
# process  O10F-60_neutral
# process  O10F-60_sad
# process  O12M-64_disgust
# process  O12M-64_happy
# process  O12M-64_anger
# process  O12M-64_content
# process  O12M-64_fear
# process  O12M-64_neutral
# process  O12M-64_surprise
# process  O12M-64_sad
# process  O15M-69_disgust
# process  O15M-69_anger
# process  O15M-69_content
# process  O15M-69_sad
# process  O15M-69_happy
# process  O15M-69_neutral
# process  O15M-69_fear
# process  O16F-64_disgust
# process  O15M-69_surprise
# process  O16F-64_happy
# process  O16F-64_fear
# process  O16F-64_anger
# process  O16F-64_content
# process  O16F-64_surprise
# process  O16F-64_sad
# process  O16F-64_neutral
# process  O17M-69_anger
# process  O17M-69_content
# process  O17M-69_disgust
# process  O17M-69_surprise
# process  O17M-69_happy
# process  O17M-69_fear
# process  O17M-69_neutral
# process  O17M-69_sad
# process  O19F-60_content
# process  O19F-60_disgust
# process  O19F-60_surprise
# process  O19F-60_fear
# process  O19F-60_sad
# process  O20M-65_disgust
# process  O20M-65_content
# process  O20M-65_happy
# process  O20M-65_neutral
# process  O20M-65_fear
# process  O20M-65_anger
# process  O21M-65_anger
# process  O21M-65_disgust
# process  O20M-65_surprise
# process  O21M-65_content
# process  O21M-65_fear
# process  O20M-65_sad
# process  O22F-61_anger
# process  O21M-65_surprise
# process  O21M-65_neutral
# process  O22F-61_content
# process  O21M-65_sad
# process  O21M-65_happy
# process  O22F-61_happy
# process  O22F-61_fear
# process  O22F-61_neutral
# process  O22F-61_disgust
# process  O23F-66_anger
# process  O23F-66_disgust
# process  O23F-66_content
# process  O22F-61_surprise
# process  O22F-61_sad
# process  O23F-66_fear
# process  O23F-66_happy
# process  O23F-66_sad
# process  O23F-66_neutral
# process  O24F-62_content
# process  O24F-62_disgust
# process  O23F-66_surprise
# process  O24F-62_happy
# process  O24F-62_anger
# process  O24F-62_fear
# process  O24F-62_neutral
# process  O24F-62_surprise
# process  O24F-62_sad
# process  O26F-64_anger
# process  O26F-64_neutral
# process  O26F-64_content
# process  O26F-64_fear
# process  O26F-64_disgust
# process  O26F-64_happy
# process  O26F-64_sad
# process  O26F-64_surprise
# process  O27F-65_fear
# process  O28F-64_happy
# process  O28F-64_content
# process  O28F-64_neutral
# process  O28F-64_disgust
# process  O28F-64_fear
# process  O28F-64_anger
# process  O29F-63_anger
# process  O28F-64_sad
# process  O28F-64_surprise
# process  O29F-63_content
# process  O29F-63_disgust
# process  O29F-63_fear
# process  O29F-63_sad
# process  O29F-63_surprise
# process  O29F-63_happy
# process  O29F-63_neutral
# process  O34F-65_disgust
# process  O34F-65_content
# process  O34F-65_anger
# process  O34F-65_happy
# process  O34F-65_neutral
# process  O34F-65_fear
# process  O34F-65_surprise
# process  O34F-65_sad
# process  O35M-66_content
# process  O35M-66_anger
# process  O35M-66_neutral
# process  O35M-66_disgust
# process  O35M-66_happy
# process  O35M-66_fear
# process  O35M-66_sad
# process  O35M-66_surprise
# process  O38F-65_anger
# process  O38F-65_disgust
# process  O38F-65_content
# process  O38F-65_fear
# process  O38F-65_neutral
# process  O38F-65_sad
# process  O38F-65_surprise
# process  O40F-61_anger
# process  O38F-65_happy
# process  O40F-61_sad
# process  O40F-61_fear
# process  O40F-61_content
# process  O40F-61_disgust
# process  O40F-61_happy
# process  O40F-61_neutral
# process  O41F-72_content
# process  O41F-72_anger
# process  O41F-72_disgust
# process  O40F-61_surprise
# process  O41F-72_fear
# process  O41F-72_sad
# process  O41F-72_neutral
# process  O41F-72_happy
# process  O41F-72_surprise
# process  O42M-75_happy
# process  O43F-62_disgust
# process  O43F-62_anger
# process  O42M-75_surprise
# process  O43F-62_content
# process  O42M-75_neutral
# process  O43F-62_sad
# process  O43F-62_neutral
# process  O43F-62_surprise
# process  O43F-62_happy
# process  O43F-62_fear
# process  O45F-65_happy
# process  O45F-65_disgust
# process  O45F-65_anger
# process  O45F-65_content
# process  O45F-65_neutral
# process  O45F-65_fear
# process  O45F-65_surprise
# process  O45F-65_sad
# process  O47F-60_anger
# process  O47F-60_neutral
# process  O47F-60_content
# process  O47F-60_fear
# process  O47F-60_happy
# process  O47F-60_disgust
# process  O48F-65_disgust
# process  O48F-65_content
# process  O47F-60_surprise
# process  O47F-60_sad
# process  O48F-65_anger
# process  O49F-65_anger
# process  O48F-65_neutral
# process  O48F-65_happy
# process  O48F-65_sad
# process  O48F-65_surprise
# process  O48F-65_fear
# process  O49F-65_happy
# process  O49F-65_disgust
# process  O49F-65_neutral
# process  O49F-65_content
# process  O49F-65_sad
# process  O49F-65_surprise
# process  O50M-65_disgust
# process  O50M-65_anger
# process  O50M-65_content
# process  O50M-65_sad
# process  O50M-65_fear
# process  O50M-65_surprise
# process  O51F-60_anger
# process  O50M-65_neutral
# process  O50M-65_happy
# process  O51F-60_neutral
# process  O51F-60_disgust
# process  O51F-60_happy
# process  O51F-60_content
# process  O51F-60_fear
# process  O52F-62_disgust
# process  O51F-60_surprise
# process  O52F-62_anger
# process  O52F-62_content
# process  O52F-62_fear
# process  O52F-62_surprise
# process  O52F-62_sad
# process  O52F-62_happy
# process  O53F-64_content
# process  O52F-62_neutral
# process  O53F-64_anger
# process  O53F-64_disgust
# process  O53F-64_happy
# process  O53F-64_sad
# process  O53F-64_neutral
# process  O53F-64_fear
# process  O53F-64_surprise
# process  O55M-64_disgust
# process  O55M-64_anger
# process  O55M-64_fear
# process  O55M-64_content
# process  O55M-64_happy
# process  O56F-65_disgust
# process  O55M-64_neutral
# process  O55M-64_sad
# process  O56F-65_anger
# process  O56F-65_content
# process  O55M-64_surprise
# process  O56F-65_happy
# process  O56F-65_neutral
# process  O56F-65_surprise
# process  O58M-64_anger
# process  O56F-65_sad
# process  O56F-65_fear
# process  O58M-64_neutral
# process  O58M-64_fear
# process  O58M-64_content
# process  O58M-64_disgust
# process  O58M-64_happy
# process  O59M-65_fear
# process  O58M-64_sad
# process  O58M-64_surprise
# process  O59M-65_content
# process  O59M-65_anger
# process  O59M-65_disgust
# process  O59M-65_sad
# process  O59M-65_neutral
# process  O59M-65_surprise
# process  O59M-65_happy
# process  O63M-61_anger
# process  O63M-61_content
# process  O63M-61_happy
# process  O63M-61_neutral
# process  O63M-61_fear
# process  O63M-61_disgust
# process  O64M-65_content
# process  O63M-61_surprise
# process  O64M-65_anger
# process  O63M-61_sad
# process  O64M-65_disgust
# process  O64M-65_neutral
# process  O64M-65_fear
# process  O64M-65_happy
# process  O64M-65_sad
# process  O64M-65_surprise
# process  O65M_disgust
# process  O65M_content
# process  O65M_anger
# process  O66M_anger
# process  O65M_neutral
# process  O65M_surprise
# process  O65M_sad
# process  O65M_fear
# process  O65M_happy
# process  O66M_fear
# process  O66M_disgust
# process  O66M_content
# process  O66M_surprise
# process  O66M_sad
# process  O66M_happy
# process  O67M_anger
# process  O66M_neutral
# process  O67M_neutral
# process  O67M_disgust
# process  O67M_sad
# process  O67M_content
# process  O67M_happy
# process  O67M_fear
# process  O68M_anger
# process  O68M_disgust_2
# process  O68M_content
# process  O68M_fear
# process  O67M_surprise
# process  O68M_surprise
# process  O68M_sad
# process  O68M_neutral
# process  O68M_happy
# process  O69M_anger
# process  O69M_content
# process  O69M_sad
# process  O69M_neutral
# process  O69M_fear
# process  O69M_happy
# process  O69M_surprise
# process  O69M_disgust
# process  O70M_anger
# process  O70M_disgust
# process  O70M_neutral
# process  O70M_fear
# process  O70M_content
# process  O70M_happy
# process  O70M_sad
# process  O71M_anger
# process  O71M_disgust
# process  O71M_content
# process  O70M_surprise
# process  O71M_neutral
# process  O71M_surprise
# process  O71M_sad
# process  O71M_happy
# process  O71M_fear
# process  Y10M-22_anger
# process  Y10M-22_disgust
# process  Y10M-22_neutral
# process  Y10M-22_fear
# process  Y10M-22_happy
# process  Y10M-22_content
# process  Y11M-20_disugst
# process  Y11M-20_content
# process  Y11M-20_anger
# process  Y10M-22_sad
# process  Y10M-22_surprise
# process  Y11M-20_sad
# process  Y11M-20_happy
# process  Y11M-20_fear
# process  Y11M-20_neutral
# process  Y12F-18_disgust
# process  Y11M-20_surprise
# process  Y12F-18_fear
# process  Y12F-18_content
# process  Y12F-18_anger
# process  Y12F-18_happy
# process  Y12F-18_neutral
# process  Y13F-20_anger
# process  Y12F-18_surprise
# process  Y12F-18_sad
# process  Y13F-20_content
# process  Y13F-20_fear
# process  Y13F-20_happy
# process  Y13F-20_sad
# process  Y13F-20_disgust
# process  Y13F-20_neutral
# process  Y14F-21_anger
# process  Y14F-21_content
# process  Y14F-21_fear
# process  Y13F-20_surprise
# process  Y14F-21_disgust
# process  Y14F-21_sad
# process  Y14F-21_happy
# process  Y14F-21_surprise
# process  Y15M-20_anger
# process  Y14F-21_neutral
# process  Y15M-20_disgust
# process  Y15M-20_happy
# process  Y15M-20_neutral
# process  Y15M-20_fear
# process  Y15M-20_content
# process  Y15M-20_sad
# process  Y15M-20_surprise
# process  Y16M-21_disgust
# process  Y16M-21_anger
# process  Y16M-21_content
# process  Y16M-21_fear
# process  Y16M-21_happy
# process  Y16M-21_surprise
# process  Y16M-21_neutral
# process  Y16M-21_sad
# process  Y17F-33_fear_1
# process  Y18F-18_anger
# process  Y18F-18_content
# process  Y18F-18_happy
# process  Y18F-18_sad
# process  Y18F-18_fear
# process  Y18F-18_surprise_2
# process  Y18F-18_disgust
# process  Y18F-18_neutral
# process  Y19F-19_happy
# process  Y19F-19_fear
# process  Y19F-19_content
# process  Y19F-19_neutral
# process  Y19F-19_anger
# process  Y19F-19_disgust
# process  Y19F-19_surprise
# process  Y1M-19_content
# process  Y19F-19_sad
# process  Y1M-19_anger
# process  Y1M-19_disgust
# process  Y1M-19_surprise
# process  Y21M-21_anger
# process  Y1M-19_fear
# process  Y1M-19_happy
# process  Y1M-19_neutral
# process  Y1M-19_sad
# process  Y21M-21_disgust
# process  Y21M-21_content
# process  Y21M-21_fear
# process  Y21M-21_neutral
# process  Y21M-21_happy
# process  Y21M-21_surprise
# process  Y22F-30_content
# process  Y22F-30_disgust
# process  Y22F-30_anger
# process  Y21M-21_sad
# process  Y22F-30_fear
# process  Y22F-30_happy
# process  Y22F-30_sad
# process  Y22F-30_neutral
# process  Y22F-30_surprise
# process  Y23F-30_disgust
# process  Y23F-30_content
# process  Y23F-30_fear
# process  Y23F-30_happy
# process  Y23F-30_anger
# process  Y23F-30_sad
# process  Y23F-30_surprise
# process  Y24M-19_content
# process  Y23F-30_neutral
# process  Y24M-19_disgust
# process  Y24M-19_anger
# process  Y24M-19_happy
# process  Y24M-19_surprise
# process  Y24M-19_sad_1
# process  Y24M-19_neutral
# process  Y24M-19_fear
# process  Y25F-33_fear
# process  Y25F-33_happy
# process  Y25F-33_content
# process  Y25F-33_anger
# process  Y25F-33_disgust
# process  Y26F-32_content
# process  Y25F-33_sad_2
# process  Y26F-32_anger
# process  Y25F-33_neutral
# process  Y25F-33_surprise
# process  Y26F-32_fear
# process  Y26F-32_disgust
# process  Y26F-32_nuetral
# process  Y26F-32_surprise
# process  Y26F-32_sad
# process  Y26F-32_happy
# process  Y28M-20_content
# process  Y28M-20_anger
# process  Y28M-20_disgust
# process  Y29M-21_anger
# process  Y28M-20_fear
# process  Y28M-20_neutral
# process  Y28M-20_sad
# process  Y28M-20_surprise
# process  Y28M-20_happy
# process  Y29M-21_disgust
# process  Y29M-21_content
# process  Y29M-21_fear
# process  Y29M-21_happy
# process  Y29M-21_neutral
# process  Y2M-21_disgust
# process  Y2M-21_content
# process  Y2M-21_fear
# process  Y29M-21_surprise
# process  Y2M-21_anger
# process  Y29M-21_sad
# process  Y2M-21_suprise
# process  Y2M-21_neutral
# process  Y30M-25_anger
# process  Y2M-21_sad
# process  Y2M-21_happy
# process  Y30M-25_fear
# process  Y30M-25_neutral
# process  Y30M-25_happy
# process  Y30M-25_disgust
# process  Y30M-25_content
# process  Y30M-25_sad
# process  Y31F-30_anger
# process  Y30M-25_surprise
# process  Y31F-30_disgust
# process  Y31F-30_content
# process  Y31F-30_surprise
# process  Y31F-30_happy
# process  Y31F-30_neutral
# process  Y31F-30_sad
# process  Y31F-30_fear
# process  Y32F-20_anger
# process  Y32F-20_disgust_1
# process  Y32F-20_sad
# process  Y32F-20_fear_2
# process  Y32F-20_content
# process  Y32F-20_neutral
# process  Y32F-20_happy
# process  Y33M-25_content
# process  Y33M-25_disgust
# process  Y32F-20_surprise
# process  Y33M-25_fear
# process  Y33M-25_anger
# process  Y33M-25_sad
# process  Y33M-25_neutral
# process  Y33M-25_happy
# process  Y33M-25_surprise
# process  Y35M-20_anger
# process  Y35M-20_content
# process  Y35M-20_fear
# process  Y35M-20_sad
# process  Y35M-20_happy
# process  Y35M-20_surprise
# process  Y35M-20_neutral
# process  Y35M-20_disgust
# process  Y36M-30_happy
# process  Y36M-30_content
# process  Y36M-30_fear
# process  Y36M-30_anger
# process  Y36M-30_disgust_1
# process  Y37F-32_anger
# process  Y37F-32_content
# process  Y36M-30_neutral
# process  Y36M-30_surprise
# process  Y36M-30_sad
# process  Y37F-32_fear
# process  Y37F-32_surprise
# process  Y37F-32_happy
# process  Y37F-32_disgust
# process  Y37F-32_sad
# process  Y37F-32_neutral
# process  Y38F-24_disgust
# process  Y38F-24_anger
# process  Y38F-24_happy
# process  Y38F-24_fear
# process  Y38F-24_content
# process  Y38F-24_neutral
# process  Y39F-25_content
# process  Y39F-25_anger
# process  Y38F-24_surprise
# process  Y39F-25_disgust
# process  Y38F-24_sad
# process  Y39F-25_surprise
# process  Y39F-25_fear
# process  Y39F-25_happy
# process  Y3F-20_anger
# process  Y39F-25_neutral
# process  Y39F-25_sad
# process  Y3F-20_content
# process  Y3F-20_neutral
# process  Y3F-20_disgust
# process  Y3F-20_fear
# process  Y3F-20_happy
# process  Y3F-20_sad
# process  Y40F-28_disgust
# process  Y40F-28_fear
# process  Y3F-20_surprise
# process  Y40F-28_content
# process  Y40F-28_anger
# process  Y40F-28_surprise
# process  Y41M-19_anger_1
# process  Y40F-28_sad
# process  Y40F-28_neutral
# process  Y40F-28_happy
# process  Y41M-19_fear
# process  Y41M-19_disgust
# process  Y41M-19_happy
# process  Y41M-19_neutral
# process  Y41M-19_sad
# process  Y41M-19_content
# process  Y41M-19_surprise
# process  Y44M-26_content
# process  Y44M-26_disgust
# process  Y44M-26_anger
# process  Y44M-26_happy
# process  Y44M-26_neutral
# process  Y44M-26_surprise
# process  Y44M-26_fear
# process  Y44M-26_sad
# process  Y46M-18_disgust
# process  Y46M-18_anger
# process  Y46M-18_content
# process  Y46M-18_fear
# process  Y46M-18_sad
# process  Y46M-18_surprise
# process  Y46M-18_happy
# process  Y46M-18_neutral
# process  Y47M-23_anger
# process  Y47M-23_content
# process  Y47M-23_fear
# process  Y47M-23_disgust
# process  Y47M-23_happy
# process  Y48F-23_content
# process  Y47M-23_neutral
# process  Y48F-23_anger
# process  Y47M-23_surprise
# process  Y47M-23_sad
# process  Y48F-23_surprise
# process  Y48F-23_neutral
# process  Y48F-23_sad
# process  Y48F-23_disgust
# process  Y48F-23_fear
# process  Y48F-23_happy
# process  Y49M-23_anger
# process  Y49M-23_disgust
# process  Y49M-23_content
# process  Y49M-23_happy
# process  Y49M-23_fear
# process  Y49M-23_surprise
# process  Y49M-23_sad
# process  Y4F-19_anger
# process  Y4F-19_disgust
# process  Y49M-23_neutral
# process  Y4F-19_content
# process  Y4F-19_surprise
# process  Y4F-19_sad
# process  Y4F-19_happy
# process  Y4F-19_neutral
# process  Y4F-19_fear
# process  Y50F-24_happy
# process  Y50F-24_content
# process  Y50F-24_anger
# process  Y50F-24_neutral
# process  Y50F-24_fear
# process  Y50F-24_disgust
# process  Y51F-23_anger
# process  Y51F-23_content
# process  Y50F-24_surprise
# process  Y50F-24_sad
# process  Y51F-23_disgust
# process  Y51F-23_happy
# process  Y51F-23_neutral
# process  Y52F-21_content
# process  Y51F-23_surprise
# process  Y52F-21_anger
# process  Y51F-23_sad
# process  Y52F-21_surprise
# process  Y52F-21_disgust
# process  Y52F-21_neutral
# process  Y52F-21_fear
# process  Y52F-21_sad
# process  Y52F-21_happy
# process  Y53M-23_anger
# process  Y53M-23_fear
# process  Y53M-23_happy
# process  Y53M-23_content
# process  Y53M-23_disgust
# process  Y53M-23_sad
# process  Y53M-23_neutral
# process  Y54M-26_anger
# process  Y54M-26_content
# process  Y54M-26_disgust
# process  Y53M-23_surprise
# process  Y54M-26_neutral
# process  Y54M-26_fear
# process  Y55M-24_anger
# process  Y54M-26_sad
# process  Y54M-26_happy
# process  Y54M-26_surprise
# process  Y55M-24_fear
# process  Y55M-24_content
# process  Y55M-24_neutral
# process  Y55M-24_disgust
# process  Y55M-24_happy
# process  Y56M-24_disgust
# process  Y56M-24_content
# process  Y55M-24_sad
# process  Y56M-24_anger
# process  Y55M-24_surprise
# process  Y56M-24_sad
# process  Y56M-24_happy
# process  Y56M-24_surprise
# process  Y56M-24_fear
# process  Y56M-24_neutral
# process  Y57M-23_anger
# process  Y57M-23_neutral
# process  Y57M-23_content
# process  Y57M-23_happy
# process  Y57M-23_sad
# process  Y57M-23_fear
# process  Y57M-23_disgust
# process  Y57M-23_surprise
# process  Y58M-22_happy
# process  Y59F-23_anger
# process  Y59F-23_happy
# process  Y59F-23_sad
# process  Y59F-23_neutral
# process  Y59F-23_fear
# process  Y59F-23_content
# process  Y59F-23_disgust
# process  Y5F-24_content
# process  Y59F-23_surprise
# process  Y5F-24_anger
# process  Y5F-24_fear
# process  Y5F-24_disgust
# process  Y5F-24_happy
# process  Y5F-24_surprise
# process  Y5F-24_sad
# process  Y5F-24_neutral
# process  Y60M-24_fear
# process  Y60M-24_anger
# process  Y60M-24_happy
# process  Y60M-24_content
# process  Y60M-24_disgust
# process  Y60M-24_surprise
# process  Y65F_disgust
# process  Y60M-24_sad
# process  Y65F_content
# process  Y60M-24_neutral
# process  Y65F_anger
# process  Y65F_happy
# process  Y65F_neutral
# process  Y65F_fear
# process  Y65F_sad
# process  Y66F-26_content
# process  Y65F_surprise
# process  Y66F-26_disgust
# process  Y66F-26_happy
# process  Y66F-26_anger
# process  Y66F-26_fear
# process  Y67M_disgust
# process  Y66F-26_surprise
# process  Y67M_anger
# process  Y67M_content
# process  Y66F-26_neutral
# process  Y66F-26_sad
# process  Y67M_surprise
# process  Y67M_sad
# process  Y67M_neutral
# process  Y67M_fear
# process  Y67M_happy
# process  Y69F_fear
# process  Y69F_content
# process  Y69F_disgust
# process  Y69F_happy
# process  Y69F_anger
# process  Y69F_surprise
# process  Y6F-23_disgust
# process  Y69F_sad
# process  Y6F-23_content
# process  Y69F_neutral
# process  Y6F-23_anger
# process  Y6F-23_surprise
# process  Y6F-23_fear
# process  Y6F-23_sad
# process  Y6F-23_neutral
# process  Y6F-23_happy
# process  Y71F_content
# process  Y71F_anger
# process  Y71F_disgust
# process  Y71F_neutral
# process  Y71F_fear
# process  Y71F_sad
# process  Y71F_happy
# process  Y72F_disgust
# process  Y71F_surprise
# process  Y72F_anger
# process  Y72F_fear
# process  Y72F_content
# process  Y72F_happy
# process  Y72F_surprise
# process  Y72F_neutral
# process  Y72F_sad
# process  Y74M_anger_1
# process  Y74M_happy
# process  Y74M_fear
# process  Y74M_neutral
# process  Y74M_content
# process  Y74M_sad
# process  Y74M_surprise
# process  Y75M-fear
# process  Y75M-content
# process  Y75M-anger
# process  Y75M-disgust
# process  Y75M-neutral
# process  Y75M-sad
# process  Y75M-happy
# process  Y75M-surprise
# process  Y8M-27_anger
# process  Y8M-27_content
# process  Y8M-27_neutral
# process  Y8M-27_disgust
# process  Y8M-27_happy
# process  Y8M-27_fear
# process  Y8M-27_surprise
# process  Y8M-27_sad
# process  O27F-65_anger
# process  O27F-65_surprise
# process  O27F-65_disgust
# process  O27F-65_happy
# process  O27F-65_content
# process  Y42F-20_fear
# process  Y42F-20_anger
# process  Y42F-20_disgust
# process  Y42F-20_content
# process  Y42F-20_sad
# process  Y42F-20_happy
# process  Y42F-20_surprise
# process  Y42F-20_neutral
# process  O27F-65_neutral
# process  O27F-65_sad
# process  O10F-60_surprise
# process  O19F-60_happy
# process  O19F-60_neutral
# process  O19F-60_anger
# process  Y17F-33_happy
# process  Y17F-33_neutral
# process  Y17F-33_disgust
# process  Y17F-33_sad
# process  Y17F-33_content
# process  Y17F-33_anger
# process  Y17F-33_surprise
# process  Y68M_content
# process  Y68M_surprise
# process  Y68M_sad
# process  Y68M_neutral
# process  Y68M_happy
# process  Y68M_fear
# process  Y68M_disgust
# process  Y27M-23_surprise
# process  Y27M-23_sad
# process  Y27M-23_neutral
# process  Y27M-23_happy
# process  Y27M-23_disgust
# process  Y27M-23_content
# process  Y27M-23_anger
# process  O42M-75_fear
# process  O42M-75_disgust
# process  O42M-75_content
# process  O42M-75_anger
# process  O42M-75_sad
# process  Y68M_anger
# process  O51F-60_sad
# process  Y58M-22_fear
# process  Y58M-22_disgust
# process  Y58M-22_content
# process  Y58M-22_anger
# process  Y58M-22_surprise
# process  Y58M-22_sad
# process  Y58M-22_neutral
# process  Y51F-23_fear

# %%
video_capture = cv2.VideoCapture(0) #Webcam object


while True:
    ret, frame = video_capture.read()
    #gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    #clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    #clahe_image = clahe.apply(gray)
    clahe_image = frame
    detections = detector(clahe_image, 1) #Detect the faces in the image
    vec = np.empty([68, 2], dtype = int)
    for k,d in enumerate(detections): #For each detected face
        
        shape = predictor(clahe_image, d) #Get coordinates
	
        for i in range(0,68): #There are 68 landmark points on each face
	   vec[i][0] = shape.part(i).x
	   vec[i][1] = shape.part(i).y
        out_frame = visualize_facial_landmarks(clahe_image,vec)
        #        cv2.circle(frame, (shape.part(i).x, shape.part(i).y), 1, (0,0,255), thickness=2) #For each point, draw a red circle with thickness2 on the original frame

        cv2.imshow("image", out_frame) #Display the frame

    if cv2.waitKey(1) & 0xFF == ord('q'): #Exit program when the user presses 'q'
        break
